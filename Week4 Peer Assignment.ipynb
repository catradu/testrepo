# %% [markdown]
# # Week4 Peer Assignment

# %% [markdown]
# This is my project called *Week4 Peer Assignment* that completes the 2nd session of my course. I want to learn more about **data science**

# %% [markdown]
# * Python
# * R
# * SQL
# - Java
# - Julia
# - Scala
# + C++

# %% [markdown]
# * TensorFlow
# * NumPy
# - Pandas
# - Caffe2
# + SciKit-Learn
# + Matplotlib

# %% [markdown]
# |Tool        |Type           |
# |------------|---------------|
# |Sas         |closed source  |
# |Apache Spark|batch processor|

# %%
$\sqrt{2x+1}+3x(x-1)^2$

# %%
# Python program to perform Multiplication and Addition

num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))

print("enter which operation would you like to perform?")
ch = input("Enter any of these char for specific operation +,*: ")

result=0
if ch == '+':
    result = num1 + num2
elif ch == '*':
    result = num1 * num2
else:
    print("Input character is not recognized!")
    
print(num1, ch, num2, "=", result)

# %%
# Python program to convert minutes to hours

minutes = 153

minutes = minutes % (24*60)
hour = minutes // 60
minutes %= 60

print ("%d:%02d" % (hour, minutes))

# %% [markdown]
# ## Objectives
#
# 1. Learn coding with python
# 2. Practice on new real-time projects
#     1. In automotive industry
#     2. In banking industry
#     3. In IT industry
# 3. Complete data science course

# %% [markdown]
# ---
# Author: Catalin Radu
# ---
