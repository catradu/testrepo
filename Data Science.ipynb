# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Catalin Radu**
# Data scientist in Automotive industry

# %% [markdown]
# *I am interested to learn data science because I want to improve my skills within data management. I want to use the knowledge on job.*

# %% [markdown]
# #### My code will add two numbers and calculate the sum of it

# %%
num1 = 2.5
num2 = 3.5

sum = num1 + num2

print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of 2.5 and 3.5 is 6.0

# %% [markdown]
# 1. I am above
# ***
# 2. and beyond
# ***
# 3. the law
#     1. written
#     2. spoken
#
# Here is a [Link](https://www.lawdepot.com/blog/are-verbal-agreements-legally-binding/ "Enjoy it").
